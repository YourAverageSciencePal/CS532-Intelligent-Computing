# %%
#Importing packages here 
import os 
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import re 
from nltk.metrics.distance import edit_distance
from sklearn.feature_extraction.text import TfidfVectorizer
from tpot import TPOTClassifier

# %%
#Mounting google drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Changing the working directory to this
#This cell needs to be executed once only otherwise it will enter the except block
try:
  os.chdir(os.getcwd()+"/drive/My Drive/IC/IC Project")
except:
    print("Already in the specified folder")

# %%
df = pd.read_csv("Data.csv",lineterminator='\n',index_col=0)

# %%
#Seperating the x,y 
x = df['Tweet']
y = df['Sentiment']

# %%
#Setting fixed random seed for consistent results
np.random.seed(0)

# %%
#Now need to do pre-processing steps
#Step 1: Case folding more popularly known as lowercasing :) 
x = x.str.lower()

# %%
#Step 2: Need to remove stopwords
stop = []
with open('stop.txt','r') as f:
    for word in tqdm(f):
      stop.append(word.strip())
#print(stop)
for word in tqdm(stop):
  x = x.replace(to_replace=r'\b{}\b'.format(word),value="",regex=True)

x = x.str.split()
#print(x)
# Out:
# 102it [00:00, 102153.54it/s]
# 100%|██████████| 102/102 [00:04<00:00, 23.51it/s]

# %%
x = x.drop([16904],axis=0) #this becomes nan so dropping it
y = y.drop([16904],axis=0) #also dropping this

# %%
#dropping the rows that become empty too after cleaning
drop = []
for word,i in zip(x,range(len(x))):
  if len(word)==0:  
      drop.append(i)

# %%
x = x.drop(drop,axis=0)
y = y.drop(drop,axis=0)

# %%
#Calculating edit distance first and removing words which have edit distance of 1 with the stop-words due to stop-words corpus being too small
distance = []
for word in tqdm(stop):
  dist = []
  for line in x:
    linelist = []
    for l in line[:]:
      d = edit_distance(word,l)
      if d==1:
        line.remove(l)
#Dropping the words which have length=0
result = x[x.apply(len)==0].index

y = y.drop(result,axis=0)
x = x.drop(result,axis=0)
# Out:
# 100%|██████████| 102/102 [04:17<00:00,  2.53s/it]

# %%
#Step 4: Splitting into traning and testing data but first setting the random state to get consistent result everytime 
X_train,X_test,y_train,y_test = train_test_split(x,y)

# %%
#Step 5: Get count of words for the training data.
pseudoDict = {}
for values in X_train:
    for word in values:
        if word not in pseudoDict.keys():
            pseudoDict[word] = 1
        else:
            pseudoDict[word] = pseudoDict[word]+1

# %%
stopwords = []
threshold = 100
for val in pseudoDict:
    if pseudoDict[val]>threshold:
        stopwords.append(val)
print(stopwords)
#Removing these stopwords from the training corpus
# Out:
# ['kabhi', '.', 'allah', 'time', 'muslim']

# %%
#Step 7: Words that are present too often are also stop words.Need to remove the words after seeing what words are those
for word in tqdm(stopwords):
  for linelist in X_train:
    for token in linelist[:]:
      if token in stopwords:
        linelist.remove(token)

result = X_train[X_train.apply(len)==0].index
y_train = y_train.drop(result,axis=0)
X_train = X_train.drop(result,axis=0)
X_train = X_train.str.join(" ")
X_test = X_test.str.join(" ")
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 34.46it/s]

# %%
X_test
# Out:
# 1891                    shobey qadam aehal ba’kamaal sabit
# 1629                                              shukria.
# 2545         shuru salon gaeyki tasawwuf peyghamat bharpor
# 2593                                 bachpan singing shauq
# 11922    ithad intaykhabat numayan aksaryat kamyabi nov...
#                                ...
# 8743                               assingment mukmal enjoy
# 7230     apni company film arts bainer taley 1966 wahee...
# 12889             physical appearance comment guraiz kren.
# 714      .zulfiqar bhutto khahis unhain wazir kharja mo...
# 16964                         means rozay buht acahy guzar
# Name: Tweet, Length: 4962, dtype: object

# %%
X_train
# Out:
# 3596                                                beshak
# 5767     edhi free cancer hospital tariq road cancer 91...
# 8670                       hahhhh ufffff... mere ajaoo :-d
# 2270     unhon sarehy panch saw zaid moqablon mosalsel ...
# 4224                                         phans jaao 😁😁
#                                ...
# 11740    bani hotel jahan tehri wahan airport 15 minute...
# 4260              khalaq bezata hahahahahaha osho apricots
# 13113                             itna bura read more hide
# 10887    news parties resignation beghair wapis jayengi...
# 6783                                                unziii
# Name: Tweet, Length: 14693, dtype: object

# %%
#Step 8: Create a tf-idf representation of the training corpus 
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train) 
X_test_vec = vectorizer.transform(X_test)

# %%
#Need to do this to complete IC Project deliverable. Use tpot bish
tpot = TPOTClassifier(generations=5, population_size=20, verbosity=3, random_state=0,warm_start=True,periodic_checkpoint_folder="BestPipelines",config_dict="TPOT sparse")

# %%
tpot.fit(X_train_vec, y_train)
# Out:
# 13 operators have been imported by TPOT.
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=120, style=ProgressStyle(descript…
# Skipped pipeline #9 due to time out. Continuing to the next pipeline.
# Skipped pipeline #16 due to time out. Continuing to the next pipeline.
# Skipped pipeline #21 due to time out. Continuing to the next pipeline.
# Created new folder to save periodic pipeline: BestPipelines
# Saving periodic pipeline from pareto front to BestPipelines/pipeline_gen_1_idx_0_2020.03.27_19-41-32.py
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 index 51 is out of bounds for axis 0 with size 51.
# _pre_test decorator: _random_mutation_operator: num_test=2 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=3 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 No feature in X meets the variance threshold 0.80000.
# _pre_test decorator: _random_mutation_operator: num_test=1 index 51 is out of bounds for axis 0 with size 51.
# _pre_test decorator: _random_mutation_operator: num_test=0 No feature in X meets the variance threshold 0.10000.
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# Skipped pipeline #34 due to time out. Continuing to the next pipeline.
# Generation 1 - Current Pareto front scores:
# -1	0.6076368575373415	LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)
#
# Saving periodic pipeline from pareto front to BestPipelines/pipeline_gen_1_idx_0_2020.03.27_19-50-51.py
# _pre_test decorator: _random_mutation_operator: num_test=0 No feature in X meets the variance threshold 0.10000.
# _pre_test decorator: _random_mutation_operator: num_test=0 No feature in X meets the variance threshold 0.35000.
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=2 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 index 51 is out of bounds for axis 0 with size 51.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# Skipped pipeline #63 due to time out. Continuing to the next pipeline.
# Generation 2 - Current Pareto front scores:
# -1	0.6076368575373415	LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)
#
# Periodic pipeline was not saved, probably saved before...
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 No feature in X meets the variance threshold 0.50000.
# _pre_test decorator: _random_mutation_operator: num_test=1 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=2 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=3 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=4 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 index 51 is out of bounds for axis 0 with size 51.
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
# Skipped pipeline #76 due to time out. Continuing to the next pipeline.
# Generation 3 - Current Pareto front scores:
# -1	0.6076368575373415	LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)
#
# Periodic pipeline was not saved, probably saved before...
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l2' and loss='hinge' are not supported when dual=False, Parameters: penalty='l2', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=1 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l2' and loss='hinge' are not supported when dual=False, Parameters: penalty='l2', loss='hinge', dual=False.
# _pre_test decorator: _random_mutation_operator: num_test=1 No feature in X meets the variance threshold 0.25000.
# _pre_test decorator: _random_mutation_operator: num_test=2 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=3 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 No feature in X meets the variance threshold 0.90000.
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# Skipped pipeline #94 due to time out. Continuing to the next pipeline.
# Skipped pipeline #96 due to time out. Continuing to the next pipeline.
# Generation 4 - Current Pareto front scores:
# -1	0.6076368575373415	LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)
#
# Periodic pipeline was not saved, probably saved before...
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only dual=False, got dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=1 Unsupported set of arguments: The combination of penalty='l1' and loss='hinge' is not supported, Parameters: penalty='l1', loss='hinge', dual=True.
# _pre_test decorator: _random_mutation_operator: num_test=0 No feature in X meets the variance threshold 0.55000.
# _pre_test decorator: _random_mutation_operator: num_test=1 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=2 index 51 is out of bounds for axis 0 with size 51.
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 No feature in X meets the variance threshold 1.00000.
# _pre_test decorator: _random_mutation_operator: num_test=0 A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array..
# _pre_test decorator: _random_mutation_operator: num_test=1 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=0 Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty..
# _pre_test decorator: _random_mutation_operator: num_test=1 index 51 is out of bounds for axis 0 with size 51.
# Skipped pipeline #117 due to time out. Continuing to the next pipeline.
# Skipped pipeline #120 due to time out. Continuing to the next pipeline.
#
#
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
# TPOTClassifier(config_dict='TPOT sparse', crossover_rate=0.1, cv=5,
#                disable_update_check=False, early_stop=None, generations=5,
#                max_eval_time_mins=5, max_time_mins=None, memory=None,
#                mutation_rate=0.9, n_jobs=1, offspring_size=None,
#                periodic_checkpoint_folder='BestPipelines', population_size=20,
#                random_state=0, scoring=None, subsample=1.0, template=None,
#                use_dask=False, verbosity=3, warm_start=True)

# %%
tpot.evaluated_individuals_
# Out:
# {'BernoulliNB(CombineDFs(input_matrix, CombineDFs(input_matrix, input_matrix)), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6038245319916589,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(CombineDFs(input_matrix, CombineDFs(input_matrix, input_matrix)), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'BernoulliNB(CombineDFs(input_matrix, RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=entropy, RFE__ExtraTreesClassifier__max_features=0.3, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.9000000000000001)), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': -inf,
#   'mutation_count': 4,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(CombineDFs(input_matrix, input_matrix), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(CombineDFs(input_matrix, RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=entropy, RFE__ExtraTreesClassifier__max_features=0.55, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.1)), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': -inf,
#   'mutation_count': 4,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(CombineDFs(input_matrix, CombineDFs(input_matrix, input_matrix)), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(CombineDFs(input_matrix, input_matrix), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5932071475574021,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(CombineDFs(input_matrix, input_matrix), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5925267134711681,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(CombineDFs(input_matrix, input_matrix), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6027357031132923,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(CombineDFs(input_matrix, input_matrix), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=25), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6005582538157883,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=29), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5966782948312999,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=34), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5971552495477014,
#   'mutation_count': 4,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=63), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=34), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5951129049928532,
#   'mutation_count': 5,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=25), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',
#    'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=34), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)')},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=34), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.601034490505956,
#   'mutation_count': 4,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=34), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',
#    'BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)')},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=50), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5859932074718274,
#   'mutation_count': 4,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=63), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=6), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6065471484977849,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=63), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5843596051411605,
#   'mutation_count': 3,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=6), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=70), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5802078848082094,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.5830661387861327,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5866733636124224,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5815007257855497,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.581160358188545,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)',
#    'BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)')},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5932071475574021,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.5900763678805093,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.6027357031132923,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6020546204872341,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5615595622448836,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5510104597892569,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.43000071107759286,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.43000071107759286,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)',)},
#  'KNeighborsClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.7500000000000001, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.5), KNeighborsClassifier__n_neighbors=59, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': -inf,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'KNeighborsClassifier(SelectPercentile(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.7500000000000001, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.5), SelectPercentile__percentile=91), KNeighborsClassifier__n_neighbors=59, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': -inf,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('KNeighborsClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.7500000000000001, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.5), KNeighborsClassifier__n_neighbors=59, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',)},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=27, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.44715192578110247,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.1, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)',)},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=50, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.43027302831733333,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=61, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.4300688540834036,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=10.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)',)},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=65, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=76, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)',)},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=98, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)',)},
#  'LinearSVC(CombineDFs(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=1.0, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.9000000000000001), input_matrix), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': -inf,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('LinearSVC(CombineDFs(input_matrix, input_matrix), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(CombineDFs(input_matrix, CombineDFs(input_matrix, input_matrix)), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5744233728193717,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(CombineDFs(input_matrix, input_matrix), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(CombineDFs(input_matrix, CombineDFs(input_matrix, input_matrix)), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=1e-05)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5740832368437327,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(CombineDFs(input_matrix, CombineDFs(input_matrix, input_matrix)), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(CombineDFs(input_matrix, SelectFwe(CombineDFs(input_matrix, input_matrix), SelectFwe__alpha=0.014)), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.575103737419196,
#   'mutation_count': 3,
#   'operator_count': 2,
#   'predecessor': ('LinearSVC(CombineDFs(input_matrix, CombineDFs(input_matrix, input_matrix)), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(CombineDFs(input_matrix, input_matrix), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5742873184291162,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(CombineDFs(input_matrix, input_matrix), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.1)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5714294813696512,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(CombineDFs(input_matrix, input_matrix), LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.0001, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.0001, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.0001, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.0001, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.1, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5258277279032638,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.1, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6008305247312555,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=True)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5981760975552134,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=1e-05)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5983122445940153,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6076368575373415,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.0001, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6076368575373415,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=1.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6030085530821739,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=10.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5778259833311369,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=10.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=10.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5827264660532252,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.5768735562750744,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.1)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.57245028305289,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=1e-05)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5755806921355976,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5776900679137007,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=5.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5841556625285965,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=5.0, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=1e-05)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5885117887168432,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.0001, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=0.5, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.5, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.5908258946201537,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.34682566392527336,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.398008403686393,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5499219783429391,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5533253532052111,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=100.0, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5499220709914854,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)',)},
#  'MultinomialNB(SelectPercentile(CombineDFs(input_matrix, input_matrix), SelectPercentile__percentile=88), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'crossover_count': 2,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5591789115231861,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)',
#    'MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)')},
#  'MultinomialNB(SelectPercentile(SelectPercentile(input_matrix, SelectPercentile__percentile=97), SelectPercentile__percentile=88), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5396451236406432,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=33), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.486012733152962,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=40), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=34), MultinomialNB__alpha=100.0, MultinomialNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 5,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=34), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=40), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.49935261828266186,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.560267833050099,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=40), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)',
#    'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)')},
#  'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=True)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.4832911357808454,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=94), MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5231050187485915,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=94), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5549588628873318,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=94), MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.34682566392527336,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5744912378795435,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=True)',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.398008403686393,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.591779201837406,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.4966970098376543,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6057991272970181,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5533253532052111,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=40), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.4836994842487049,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=100.0, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5499220709914854,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=100.0, MultinomialNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'RandomForestClassifier(SelectPercentile(input_matrix, SelectPercentile__percentile=29), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.35000000000000003, RandomForestClassifier__min_samples_leaf=11, RandomForestClassifier__min_samples_split=15, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5498533026079871,
#   'mutation_count': 3,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=29), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)',)},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.7500000000000001, RandomForestClassifier__min_samples_leaf=17, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': -inf,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.1, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)',)},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.25, RandomForestClassifier__min_samples_leaf=18, RandomForestClassifier__min_samples_split=18, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': -inf,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.7500000000000001, RandomForestClassifier__min_samples_leaf=5, RandomForestClassifier__min_samples_split=9, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': -inf,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.8, RandomForestClassifier__min_samples_leaf=9, RandomForestClassifier__min_samples_split=2, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': -inf,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.45, RandomForestClassifier__min_samples_leaf=6, RandomForestClassifier__min_samples_split=3, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': -inf,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'XGBClassifier(CombineDFs(input_matrix, input_matrix), XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=2, XGBClassifier__min_child_weight=16, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.7000000000000001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.4487848795719452,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)',)},
#  'XGBClassifier(CombineDFs(input_matrix, input_matrix), XGBClassifier__learning_rate=1.0, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=20, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.35000000000000003)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.43081752382399463,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=1.0, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=20, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.35000000000000003)',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.8)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.4750555601751151,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=8, XGBClassifier__min_child_weight=14, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.3)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.42938816521366724,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=19, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.7500000000000001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.4850603292590363,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=19, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.7500000000000001)',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=19, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.7500000000000001)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.4897561281801903,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=19, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=1.0)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5044573678872263,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=19, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.7500000000000001)',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=1.0, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=11, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.35000000000000003)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.4896200737899347,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=1.0, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=20, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.35000000000000003)',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=1.0, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=20, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.35000000000000003)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.43081752382399463,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)}}

# %%
d = tpot.evaluated_individuals_ #All models evaluated

# %%
d.keys() #d is a dict
# Out:
# dict_keys(['LinearSVC(input_matrix, LinearSVC__C=0.0001, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)', 'BernoulliNB(SelectPercentile(input_matrix, SelectPercentile__percentile=88), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True)', 'BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)', 'MultinomialNB(input_matrix, MultinomialNB__alpha=100.0, MultinomialNB__fit_prior=True)', 'BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)', 'MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)', 'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=19, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.7500000000000001)', 'KNeighborsClassifier(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=gini, RFE__ExtraTreesClassifier__max_features=0.7500000000000001, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.5), KNeighborsClassifier__n_neighbors=59, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)', 'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=40), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)', 'BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)', 'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=50, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)', 'LogisticRegression(input_matrix, LogisticRegression__C=0.5, LogisticRegression__dual=False, LogisticRegression__penalty=l2)', 'MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)', 'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.25, RandomForestClassifier__min_samples_leaf=18, RandomForestClassifier__min_samples_split=18, RandomForestClassifier__n_estimators=100)', 'MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)', 'LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001)', 'XGBClassifier(input_matrix, XGBClassifier__learning_rate=1.0, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=20, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.35000000000000003)', 'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.8, RandomForestClassifier__min_samples_leaf=9, RandomForestClassifier__min_samples_split=2, RandomForestClassifier__n_estimators=100)', 'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=8, XGBClassifier__min_child_weight=14, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.3)', 'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=94), MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)', 'LinearSVC(input_matrix, LinearSVC__C=0.0001, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.0001)', 'MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False)', 'MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)', 'MultinomialNB(CombineDFs(input_matrix, input_matrix), MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=True)', 'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.8)', 'MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)', 'Bernoulli ...

# %%
models_df = pd.DataFrame(data=d) #Creating a dataframe and saved it in modelInfo.csv
#models_df.to_csv("modelInfo.csv")

# %%
#Step 9: Do SVD on the tf-idf representation to reduce dimensionality

# %%
#Step 10: Do ridge regression for feature selection to reduce dimensionality

# %%
#Step 11: Do lasso regression for feature selection to reduce dimensionality

# %%
#Step 12: Create a multi-input feed forward neural network using features obtained from step 9,10,11 and train it

# %%
#Step 13: Do hyperparameter tunning using talos

# %%
#Step 14: Do
